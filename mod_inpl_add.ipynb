# %%
import qrisp

# %%
a = qrisp.QuantumModulus(17)
b = qrisp.QuantumModulus(17)

a.m = 5
b.m = 1

qrisp.h(a)
qrisp.h(b)

temp = b.duplicate()
qrisp.cx(b, temp)

print(type(a))
print(type(b))
print(b)
b+=2
print(b)
print(b.m)

#mes_res = qrisp.multi_measurement([temp, a, b])

# for temp, a, b in mes_res.keys():
    
#     if temp is np.nan or a is np.nan:
#         continue
#     if (temp + a)%17 != b:
#         raise
# Out:
# <class 'qrisp.qtypes.quantum_modulus.QuantumModulus'>
# <class 'qrisp.qtypes.quantum_modulus.QuantumModulus'>
# Simulating 5 qubits.. |                                                      | [  0%]
# {0: 0.03125, 9: 0.03125, 1: 0.03125, 10: 0.03125, 2: 0.03125, 11: 0.03125, 3: 0.03125, 12: 0.03125, 4: 0.03125, 13: 0.03125, 5: 0.03125, 14: 0.03125, 6: 0.03125, 15: 0.03125, 7: 0.03125, 16: 0.03125, 8: 0.03125, nan: 0.03125}
# {2: 0.0625, 11: 0.0625, 3: 0.0625, 12: 0.0625, 4: 0.0625, 13: 0.0625, 5: 0.0625, 14: 0.0625, 6: 0.0625, 15: 0.0625, 7: 0.0625, 16: 0.0625, 8: 0.0625, 0: 0.03125, 9: 0.03125, 1: 0.03125, 10: 0.03125, nan: 0.03125}
# 1
