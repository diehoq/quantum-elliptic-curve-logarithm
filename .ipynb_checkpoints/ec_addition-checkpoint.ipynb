# %%
import qrisp
import src.classical.ec_arithmetic as clECarithm
import src.quantum.ec_arithmetic as qECarithm

# %%
p=7
a=5
b=4
curve = clECarithm.EllCurve(a, b, p)
# Sample input points
input_points = [(2,1), (4,5), (0,2), (5,0), (0,5), (4,2), (2,6) ] 
G_ell = clECarithm.EllPoint(3, 5)
G_qrisp = [3, 5]
mod_p = qrisp.QuantumModulus(p)

# Compare outputs
for point in input_points:
    P_ell = clECarithm.EllPoint(point[0], point[1])
    anc = qrisp.QuantumArray(qtype=mod_p, shape=(2,))
    anc[:] = [point[0], point[1]]
    result_ell = clECarithm.ell_add_generic(P_ell, G_ell, curve)
    result_qrisp = qECarithm.qrisp_ell_add_inpl(anc, G_qrisp, p)    
    print("Input Point:", point)
    print("Elliptic addition:", (result_ell.x, result_ell.y))
    print(qrisp.multi_measurement(result_qrisp))
    print()

# %%
import cProfile
with cProfile.Profile() as pr:
    p=7
    a=5
    b=4

    curve = clECarithm.EllCurve(a, b, p)
    x1 = qrisp.QuantumModulus(2**(p.bit_length())) 
    x1[:] = 1
    mod_p = qrisp.QuantumModulus(p)
    #store registers
    anc = qrisp.QuantumArray(qtype=mod_p, shape=(2,))
    #initialize the store register to the point P_0 = (3,2)
    anc[:] = [2,6]

    #Generator G = [2,2]
    G = [0,5]

    res = qECarithm.qrisp_ell_mult_add(G,anc,x1,curve)
    print(len([qb for qb in res[0].qs.qubits if qb.allocated]))
    res_compiled = res[0].qs.compile()
    print(res_compiled.depth())
    print(res_compiled.transpile().count_ops())
    #print(qrisp.multi_measurement(res))
# Out:
# 9
# 121447
# {'x': 2896, 'cx': 153384, 'h': 31338, 'p': 166428}

# %%
import pstats
results = pstats.Stats(pr).sort_stats(pstats.SortKey.TIME)
results.print_stats()
# Out:
#          305335722 function calls (304695777 primitive calls) in 256.790 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2  151.905   75.952  151.905   75.952 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:874(ancestors_jitted_wrapper)
#       129   14.589    0.113   25.972    0.201 /home/dpolimen/Qrisp/src/qrisp/uncomputation/unqomp.py:75(dag_from_qc)
# 143490/12605   13.876    0.000   15.811    0.001 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:90(transpile_inner)
#        26    6.318    0.243  184.843    7.109 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:539(topological_sort)
#   2239937    5.526    0.000    7.105    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:643(add_edge)
#  26661045    5.415    0.000    5.415    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:484(<lambda>)
#  48569283    4.578    0.000    4.578    0.000 /home/dpolimen/Qrisp/src/qrisp/uncomputation/unqomp.py:59(__eq__)
#         2    3.505    1.752  162.196   81.098 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:884(ancestors)
#  52571294    3.442    0.000    3.442    0.000 /home/dpolimen/Qrisp/src/qrisp/uncomputation/unqomp.py:47(__hash__)
#  31851803    2.259    0.000    2.259    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/qubit.py:67(__eq__)
#    218325    2.138    0.000    2.324    0.000 /usr/lib/python3.9/copy.py:258(_reconstruct)
# 1197688/1196210    2.099    0.000    4.116    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1276(append)
#       483    2.080    0.004    4.473    0.009 /home/dpolimen/Qrisp/src/qrisp/misc/utility.py:1325(retarget_instructions)
#  25743196    1.812    0.000    1.812    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/qubit.py:64(__hash__)
#        52    1.774    0.034    1.774    0.034 /home/dpolimen/Qrisp/src/qrisp/misc/depth_reduction.py:143(depth_sensitive_topological_sort)
#    132361    1.697    0.000    1.779    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:80(__init__)
#       173    1.452    0.008    9.254    0.053 /home/dpolimen/Qrisp/src/qrisp/misc/utility.py:90(get_depth_dic)
#        26    1.339    0.052    2.395    0.092 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:713(add_edges_from)
#       586    1.279    0.002    1.279    0.002 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:902(<listcomp>)
#        26    0.885    0.034  234.107    9.004 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:46(qompiler)
#    891969    0.862    0.000    1.283    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:313(__getitem__)
#   2420231    0.818    0.000    1.115    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graph.py:1274(has_edge)
#   2223137    0.814    0.000    2.367    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/convert_matrix.py:590(<genexpr>)
#   2367579    0.813    0.000    1.811    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:316(new_node_ok)
#   4004213    0.688    0.000    1.074    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/filters.py:54(__call__)
#        52    0.647    0.012   22.579    0.434 /home/dpolimen/Qrisp/src/qrisp/misc/depth_reduction.py:96(parallelize_qc)
#     74491    0.630    0.000    7.255    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/algorithms/dag.py:166(topological_generations)
# 150127/147638    0.626    0.000    1.223    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:61(merge_sessions_inner)
#  13208784    0.626    0.000    0.626    0.000 {method 'append' of 'list' objects}
#    296712    0.613    0.000    1.587    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:802(update_depth_dic)
#   2223137    0.603    0.000    1.157    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/reportviews.py:788(<genexpr>)
#   2976903    0.597    0.000    2.408    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:281(<genexpr>)
#    522684    0.589    0.000    1.201    0.000 /home/dpolimen/Qrisp/src/qrisp/misc/depth_reduction.py:73(qb_set_to_int)
#   3578833    0.566    0.000    0.566    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/instruction.py:68(__init__)
#        26    0.553    0.021    0.803    0.031 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:469(add_nodes_from)
# 8453252/8453066    0.543    0.000    3.214    0.000 {built-in method builtins.len}
#   2903409    0.539    0.000    0.551    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:136(<listcomp>)
#   1570287    0.526    0.000    1.307    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:874(successors)
# 504405/179746    0.508    0.000    0.856    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:2337(convert_to_qb_list)
#   3500656    0.505    0.000    0.670    0.000 {method 'get' of 'dict' objects}
#   4776585    0.486    0.000    0.486    0.000 {method 'update' of 'dict' objects}
# 8472622/8472358    0.485    0.000    0.485    0.000 {built-in method builtins.isinstance}
# 1260708/1260047    0.450    0.000    0.466    0.000 /home/dpolimen/Qrisp/src/qrisp/uncomputation/type_checker.py:48(is_permeable)
#        26    0.443    0.017  194.979    7.499 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:477(reorder_qc)
#        54    0.439    0.008    3.217    0.060 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/convert_matrix.py:486(to_scipy_sparse_array)
#    891969    0.420    0.000    0.420    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:274(__iter__)
#   2223083    0.419    0.000    0.433    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/reportviews.py:779(<lambda>)
#    831029    0.405    0.000    0.475    0.000 /home/dpolimen/Qrisp/src/qrisp/uncomputation/unqomp.py:35(__init__)
#   2001497    0.392    0.000    0.571    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:437(__eq__)
#    623824    0.365    0.000    4.384    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/reportviews.py:575(__iter__)
#   1147958    0.350    0.000    0.482    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graph.py:1415(get_edge_data)
#   1984602    0.318    0.000    1.965    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:272(<genexpr>)
# 104155/65032    0.318    0.000    4.361    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:440(append)
#    522684    0.313    0.000    0.359    0.000 /home/dpolimen/Qrisp/src/qrisp/misc/depth_reduction.py:53(split_integer)
#    109057    0.309    0.000    0.310    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/qubit.py:50(__init__)
#   2903409    0.301    0.000    0.316    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:137(<listcomp>)
#    218325    0.286    0.000    2.853    0.000 /usr/lib/python3.9/copy.py:66(copy)
#    145084    0.286    0.000    1.968    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:44(merge_sessions)
#    833791    0.283    0.000    0.409    0.000 <frozen importlib._bootstrap>:1033(_handle_fromlist)
#     68647    0.249    0.000    0.572    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:211(__init__)
#      4965    0.248    0.000    0.248    0.000 {built-in method numpy.array}
#   1793531    0.236    0.000    0.236    0.000 {built-in method builtins.max}
#    603699    0.229    0.000    2.196    0.000 {built-in method builtins.sum}
#   1389956    0.228    0.000    0.312    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graphviews.py:223(reverse_edge)
#    789219    0.223    0.000    0.383    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graph.py:1643(<genexpr>)
#    594646    0.202    0.000    2.671    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:271(__len__)
#    297323    0.191    0.000    0.298    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:283(__getitem__)
#   4198547    0.188    0.000    0.188    0.000 {built-in method builtins.id}
#   1384355    0.167    0.000    0.167    0.000 {method 'copy' of 'dict' objects}
#    522684    0.160    0.000    0.217    0.000 /home/dpolimen/Qrisp/src/qrisp/misc/depth_reduction.py:74(<listcomp>)
#   1576715    0.159    0.000    0.301    0.000 {built-in method builtins.iter}
#         1    0.151    0.151    0.229    0.229 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:914(qft_cancellation)
#        53    0.142    0.003    9.374    0.177 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1074(depth)
#    130885    0.141    0.000    0.142    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:103(<dictcomp>)
#    217943    0.139    0.000    3.129    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/instruction.py:109(copy)
#   1578938    0.137    0.000    0.137    0.000 {built-in method builtins.hasattr}
#    879629    0.135    0.000    0.261    0.000 {method 'sort' of 'list' objects}
#    179340    0.131    0.000    0.232    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:2370(convert_to_cb_list)
#   1114046    0.130    0.000    0.139    0.000 {method 'items' of 'dict' objects}
#    121781    0.128    0.000    0.265    0.000 {method 'index' of 'list' objects}
# 40842/37634    0.127    0.000    2.243    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:617(__init__)
#   2084934    0.126    0.000    0.126    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/filters.py:20(no_filter)
#    442602    0.124    0.000    0.291    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:311(<genexpr>)
#     86656    0.123    0.000    0.349    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/ipykernel/ipkernel.py:775(_clean_thread_parent_frames)
#    892605    0.120    0.000    0.120    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:267(__init__)
#     42940    0.118    0.000    0.123    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:236(add_qubit)
#       448    0.117    0.000    3.825    0.009 /home/dpolimen/Qrisp/src/qrisp/environments/gate_wrap_environment.py:131(compile)
#   2163584    0.117    0.000    0.117    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:60(<lambda>)
#      6791    0.109    0.000    0.109    0.000 {built-in method numpy.asarray}
#         1    0.099    0.099    0.099    0.099 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:894(count_ops)
#    477356    0.098    0.000    0.101    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:1250(__setattr__)
#     72204    0.096    0.000    0.329    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:440(__init__)
#       716    0.095    0.000    2.358    0.003 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/algorithms/dag.py:219(<dictcomp>)
#      2767    0.095    0.000    0.198    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:286(reorder_quantum_variables)
#    296592    0.091    0.000    0.118    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:348(<listcomp>)
#    218325    0.091    0.000    0.096    0.000 {method '__reduce_ex__' of 'object' objects}
#    459631    0.088    0.000    0.088    0.000 {built-in method builtins.getattr}
#    311832    0.082    0.000    0.451    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graph.py:453(__contains__)
#    333078    0.081    0.000    0.112    0.000 {method 'intersection' of 'set' objects}
#    297323    0.077    0.000    0.077    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:483(<lambda>)
#     52748    0.076    0.000    2.028    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:314(multi_session_merge)
#     43328    0.075    0.000    0.125    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/ipykernel/ipkernel.py:790(<setcomp>)
#        26    0.073    0.003    0.073    0.003 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:598(<dictcomp>)
#     12605    0.072    0.000   16.061    0.001 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:30(transpile)
# 836290/836158    0.071    0.000    0.071    0.000 {built-in method builtins.hash}
#    297323    0.070    0.000    0.368    0.000 /usr/lib/python3.9/_collections_abc.py:766(__contains__)
# 1558/1510    0.069    0.000    3.300    0.002 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/utils/backends.py:409(__call__)
#    218233    0.068    0.000    2.954    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:145(copy)
#     43328    0.068    0.000    0.083    0.000 /usr/lib/python3.9/threading.py:1348(enumerate)
#    921584    0.067    0.000    0.067    0.000 {built-in method builtins.issubclass}
#    297349    0.066    0.000    0.079    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graph.py:1642(<genexpr>)
#     34338    0.064    0.000    0.218    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:565(__init__)
#     27498    0.059    0.000    0.176    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:476(inverse)
# 28571/5159    0.051    0.000    0.081    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:329(recursive_qs_search)
#    297959    0.051    0.000    0.090    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graph.py:2010(bunch_iter)
#         3    0.051    0.017    3.176    1.059 /home/dpolimen/Qrisp/src/qrisp/environments/iteration_environment.py:243(<listcomp>)
#    389952    0.050    0.000    0.050    0.000 /usr/lib/python3.9/threading.py:1069(ident)
#  1402/446    0.049    0.000    3.185    0.007 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:690(inverse)
# 135566/47856    0.049    0.000    0.058    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:483(check_alloc)
#      4413    0.048    0.000    0.078    0.000 /home/dpolimen/Qrisp/src/qrisp/logic_synthesis/gray_synthesis.py:328(gray_synth_qc)
#      2477    0.047    0.000  131.508    0.053 /home/dpolimen/Qrisp/src/qrisp/environments/quantum_environments.py:406(__exit__)
#        25    0.046    0.002  110.453    4.418 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:765(compile)
#    218325    0.045    0.000    0.063    0.000 /usr/lib/python3.9/copyreg.py:94(__newobj__)
#    909212    0.045    0.000    0.045    0.000 {method 'keys' of 'dict' objects}
#       636    0.044    0.000    0.149    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/filters.py:51(__init__)
#         1    0.042    0.042  131.443  131.443 /home/dpolimen/Qrisp/src/qrisp/environments/iteration_environment.py:159(compile)
#      5256    0.042    0.000    0.042    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:120(<listcomp>)
#    153316    0.040    0.000    0.053    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:310(<genexpr>)
# 40842/37634    0.037    0.000    2.278    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:824(__init__)
#     20074    0.037    0.000    0.074    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:482(copy)
#       716    0.036    0.000    2.178    0.003 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/algorithms/dag.py:220(<listcomp>)
#    132361    0.035    0.000    0.036    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:143(<dictcomp>)
#      4876    0.035    0.000    0.067    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:311(to_op)
#    311912    0.034    0.000    7.289    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/algorithms/dag.py:244(topological_sort)
#      7465    0.034    0.000    0.553    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/controlled_operations.py:56(multi_controlled_u3_circ)
#      6646    0.034    0.000    0.034    0.000 {method 'round' of 'numpy.ndarray' objects}
#    156391    0.032    0.000    0.056    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:613(<lambda>)
#     25390    0.032    0.000    2.077    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:839(inverse)
#    129021    0.030    0.000    0.032    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1499(<listcomp>)
#      5256    0.030    0.000    0.030    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:224(<listcomp>)
#     18403    0.030    0.000    2.042    0.000 /home/dpolimen/Qrisp/src/qrisp/core/library.py:25(append_operation)
#    144881    0.029    0.000    0.038    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:316(<lambda>)
#    263403    0.029    0.000    0.031    0.000 {method 'issubset' of 'set' objects}
#   203/113    0.028    0.000    1.030    0.009 /home/dpolimen/Qrisp/src/qrisp/environments/control_environment.py:141(compile)
#      2952    0.027    0.000    0.052    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:302(identify_sessions_in_environment)
#      8687    0.026    0.000    0.308    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/custom_control_environment.py:225(__init__)
#      5256    0.025    0.000    0.060    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:223(resolve_naming_collisions)
#     51165    0.025    0.000    0.030    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:78(reordering_transpile_predicate)
#     51/29    0.023    0.000    1.722    0.059 /home/dpolimen/Qrisp/src/qrisp/uncomputation/unqomp.py:299(uncompute_qc)
# 18977/18851    0.023    0.000    0.048    0.000 /home/dpolimen/Qrisp/src/qrisp/misc/utility.py:614(find_qs)
#   448/102    0.022    0.000    8.175    0.080 /home/dpolimen/Qrisp/src/qrisp/misc/utility.py:362(wrapped_function)
# 13804/13024    0.022    0.000    0.445    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:291(control)
#     50010    0.021    0.000    0.021    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:521(<listcomp>)
#    129021    0.020    0.000    0.020    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1510(<listcomp>)
#    230493    0.020    0.000    0.020    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:291(<lambda>)
#      2930    0.019    0.000    0.026    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:1234(__del__)
#    220324    0.018    0.000    0.018    0.000 {built-in method __new__ of type object at 0x906da0}
#     12526    0.018    0.000    8.689    0.001 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:829(transpile)
#      2767    0.018    0.000    1.018    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:265(merge_env_stack)
#        26    0.017    0.001    0.030    0.001 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:605(<dictcomp>)
#    354046    0.017    0.000    0.017    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1074(<lambda>)
#       201    0.016    0.000    0.125    0.001 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:396(extend)
#      2477    0.016    0.000    0.085    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/quantum_environments.py:364(__enter__)
#    136121    0.016    0.000    0.016    0.000 {method 'update' of 'set' objects}
#     66778    0.016    0.000    0.059    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:67(<lambda>)
#      2477    0.015    0.000    0.041    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:1258(get_active_quantum_sessions)
#    129021    0.015    0.000    0.015    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1476(<listcomp>)
#  2073/452    0.015    0.000    2.829    0.006 /home/dpolimen/Qrisp/src/qrisp/environments/quantum_environments.py:477(compile)
#    130885    0.015    0.000    0.015    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:111(<dictcomp>)
#       509    0.015    0.000    1.264    0.002 /home/dpolimen/Qrisp/src/qrisp/arithmetic/SBP_arithmetic.py:61(multi_controlled_U_g)
#      2011    0.014    0.000    0.026    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:508(clearcopy)
#    113688    0.014    0.000    0.014    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:64(<lambda>)
#       229    0.013    0.000    1.320    0.006 /home/dpolimen/Qrisp/src/qrisp/core/library.py:1142(QFT_inner)
#    145912    0.013    0.000    0.013    0.000 {method 'pop' of 'list' objects}
#    129021    0.012    0.000    0.012    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1479(<listcomp>)
#     23130    0.011    0.000    0.143    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:595(inverse)
#      8826    0.011    0.000    0.011    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#    2215/1    0.011    0.000   11.339   11.339 /home/dpolimen/Qrisp/src/qrisp/environments/custom_control_environment.py:136(adaptive_control_function)
#    129021    0.010    0.000    0.010    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1480(<listcomp>)
#     11311    0.010    0.000    0.065    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:53(_wrapfunc)
#     66658    0.010    0.000    0.014    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:1242(__hash__)
#      6413    0.010    0.000    0.045    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:40(_wrapit)
# 102750/102736    0.010    0.000    0.010    0.000 {method 'values' of 'dict' objects}
#    101/42    0.010    0.000    1.373    0.033 /home/dpolimen/Qrisp/src/qrisp/environments/custom_control_environment.py:199(compile)
#        54    0.010    0.000    0.010    0.000 {built-in method scipy.sparse._sparsetools.coo_tocsr}
#      2986    0.010    0.000    0.014    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numpy/lib/twodim_base.py:158(eye)
#     11208    0.010    0.000    0.095    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:40(XGate)
#       444    0.010    0.000    0.017    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/gate_wrap_environment.py:196(<dictcomp>)
#       444    0.009    0.000    0.014    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/gate_wrap_environment.py:150(<dictcomp>)
#     12605    0.009    0.000    0.009    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:52(<dictcomp>)
#      8206    0.009    0.000    1.238    0.000 /home/dpolimen/Qrisp/src/qrisp/core/library.py:33(cx)
#      8701    0.009    0.000    0.735    0.000 /home/dpolimen/Qrisp/src/qrisp/core/library.py:741(p)
#   480/144    0.008    0.000    0.030    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/assumptions.py:509(_ask)
#     19453    0.008    0.000    0.011    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/gate_wrap_environment.py:164(<listcomp>)
#      2957    0.008    0.000    0.024    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:123(__init__)
#      3292    0.008    0.000    0.129    0.000 /home/dpolimen/Qrisp/src/qrisp/mcx_algs/gray.py:44(gray_multi_cx)
#     15845    0.008    0.000    0.009    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:93(parallellization_transpile_predicate)
#      4413    0.008    0.000    0.096    0.000 /home/dpolimen/Qrisp/src/qrisp/logic_synthesis/gray_synthesis.py:423(__init__)
#      8791    0.007    0.000    0.062    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:68(PGate)
#      9364    0.007    0.000    0.158    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:52(CXGate)
#     43328    0.007    0.000    0.007    0.000 {method '__exit__' of '_thread.lock' objects}
#      2477    0.007    0.000    0.007    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:1262(<listcomp>)
#     48054    0.006    0.000    0.006    0.000 {method 'extend' of 'list' objects}
#      4173    0.006    0.000    0.171    0.000 /home/dpolimen/Qrisp/src/qrisp/logic_synthesis/gray_synthesis.py:485(gray_phase_synth_qb_list)
#     18976    0.006    0.000    0.008    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/gate_wrap_environment.py:184(<listcomp>)
#     50010    0.006    0.000    0.006    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:522(<listcomp>)
#  3993/612    0.006    0.000    0.759    0.001 /home/dpolimen/Qrisp/src/qrisp/environments/custom_control_environment.py:254(inverse)
#       336    0.006    0.000    0.012    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/facts.py:599(deduce_all_facts)
#      5916    0.006    0.000    0.011    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/algorithms/traversal/breadth_first_search.py:19(generic_bfs_edges)
#     27498    0.005    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:502(<listcomp>)
#      2477    0.005    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:1265(<listcomp>)
#        65    0.005    0.000    1.785    0.027 /home/dpolimen/Qrisp/src/qrisp/uncomputation/uncomputation.py:88(uncompute)
#       437    0.005    0.000    0.080    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_variable.py:215(__init__)
#       312    0.005    0.000    1.607    0.005 /home/dpolimen/Qrisp/src/qrisp/uncomputation/unqomp.py:188(uncompute_node)
#     12913    0.005    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/compilation_acceleration.py:27(__enter__)
#     27608    0.005    0.000    0.005    0.000 {method 'find' of 'str' objects}
#     20135    0.005    0.000    0.005    0.000 {method 'union' of 'set' objects}
#       255    0.004    0.000    0.034    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:309(clear_qubits)
#      1999    0.004    0.000    0.745    0.000 /home/dpolimen/Qrisp/src/qrisp/arithmetic/SBP_arithmetic.py:109(crz_helper)
# 4694/1360    0.004    0.000    0.020    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/control_environment.py:369(convert_to_custom_control)
#       334    0.004    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/uncomputation/unqomp.py:389(detect_double_alloc)
#       607    0.004    0.000    0.090    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:292(request_qubits)
# 1608/1199    0.004    0.000    2.867    0.002 /home/dpolimen/Qrisp/src/qrisp/circuit/operation.py:229(inverse)
#      6413    0.004    0.000    0.057    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3269(round)
#      9496    0.004    0.000    0.009    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:90(qft_transpile_predicate)
#        54    0.004    0.000    0.004    0.000 {built-in method scipy.sparse._sparsetools.csr_has_canonical_format}
#      3215    0.004    0.000    0.004    0.000 {built-in method numpy.zeros}
#    206/60    0.004    0.000    6.194    0.103 /home/dpolimen/Qrisp/src/qrisp/environments/conjugation_environment.py:145(__enter__)
#       216    0.004    0.000    0.004    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   201/158    0.003    0.000    0.893    0.006 /home/dpolimen/Qrisp/src/qrisp/environments/quantum_inversion.py:110(compile)
#      8174    0.003    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:209(<lambda>)
#     12913    0.003    0.000    0.003    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/compilation_acceleration.py:34(__exit__)
#     14210    0.003    0.000    0.003    0.000 {method 'clear' of 'list' objects}
#       197    0.003    0.000    0.034    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_variable.py:369(delete)
#      6170    0.003    0.000    0.007    0.000 /usr/lib/python3.9/random.py:349(shuffle)
#     30207    0.003    0.000    0.003    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:289(<lambda>)
#      2068    0.003    0.000    0.016    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:281(QubitAlloc)
#      2477    0.003    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/quantum_environments.py:350(stop_dumping)
#       636    0.003    0.000    0.007    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graphviews.py:135(subgraph_view)
#     24285    0.003    0.000    0.004    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/facts.py:633(<genexpr>)
#       164    0.003    0.000    0.096    0.001 /home/dpolimen/Qrisp/src/qrisp/arithmetic/SBP_arithmetic.py:170(U_g)
#      2477    0.003    0.000    0.004    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/quantum_environments.py:337(start_dumping)
#       948    0.003    0.000    0.010    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:1037(__new__)
#     12913    0.003    0.000    0.003    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/compilation_acceleration.py:24(__init__)
#       326    0.003    0.000    0.004    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_variable.py:1060(__del__)
#      3292    0.003    0.000    0.132    0.000 /home/dpolimen/Qrisp/src/qrisp/mcx_algs/__init__.py:32(multi_cx)
# 2732/2080    0.003    0.000    0.055    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/cache.py:69(wrapper)
#      2808    0.003    0.000    0.012    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/sympify.py:101(sympify)
#      4653    0.002    0.000    0.010    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:537(swapaxes)
#      4653    0.002    0.000    0.002    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#       120    0.002    0.000    0.107    0.001 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:410(gen_hybrid_mcx_data)
#       831    0.002    0.000    0.002    0.000 {built-in method posix.stat}
#        60    0.002    0.000    0.729    0.012 /home/dpolimen/Qrisp/src/qrisp/arithmetic/SBP_arithmetic.py:185(sb_polynomial_encoder)
#      3881    0.002    0.000    0.050    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:363(to_gate)
#       184    0.002    0.000    0.008    0.000 /usr/lib/python3.9/traceback.py:321(extract)
#      6135    0.002    0.000    0.003    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:564(clear_data)
#      6965    0.002    0.000    0.003    0.000 /usr/lib/python3.9/random.py:238(_randbelow_with_getrandbits)
#   873/819    0.002    0.000    0.004    0.000 /usr/lib/python3.9/functools.py:949(__get__)
#       206    0.002    0.000    1.488    0.007 /home/dpolimen/Qrisp/src/qrisp/environments/conjugation_environment.py:183(perform_conjugation)
#      1062    0.002    0.000    0.005    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:1372(__eq__)
#      1577    0.002    0.000    0.011    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:92(HGate)
#       791    0.002    0.000    0.003    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:316(__init__)
#       636    0.002    0.000    0.161    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graph.py:1763(subgraph)
#        78    0.002    0.000    0.003    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:589(remove_nodes_from)
#     18976    0.002    0.000    0.002    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/gate_wrap_environment.py:185(<listcomp>)
#      6228    0.002    0.000    0.003    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:906(predecessors)
#       300    0.002    0.000    0.004    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/symbol.py:606(symbols)
# 9222/9198    0.002    0.000    0.005    0.000 {built-in method builtins.all}
#      1315    0.002    0.000    0.003    0.000 {method 'remove' of 'list' objects}
#      1432    0.002    0.000    0.008    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:277(add_qubit)
#       216    0.002    0.000    0.056    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/scipy/sparse/_sputils.py:149(get_index_dtype)
#      1254    0.002    0.000    0.002    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:149(mpf_norm)
#     12605    0.002    0.000    0.002    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/transpiler.py:57(<dictcomp>)
#       384    0.002    0.000    0.069    0.000 /home/dpolimen/Qrisp/src/qrisp/core/library.py:1551(fredkin_qc)
#    100/70    0.002    0.000    0.043    0.001 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/mul.py:197(flatten)
#      2666    0.002    0.000    0.500    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:406(merge)
#       184    0.002    0.000    0.003    0.000 /usr/lib/python3.9/traceback.py:388(format)
#       918    0.002    0.000    0.008    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:289(QubitDealloc)
#       120    0.001    0.000    0.009    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/basic.py:838(subs)
#      5256    0.001    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:121(<listcomp>)
#      1272    0.001    0.000    0.002    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/coreviews.py:304(__iter__)
#        24    0.001    0.000    0.013    0.001 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/algorithms/dag.py:110(<setcomp>)
#      5256    0.001    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/core/session_merging_tools.py:225(<listcomp>)
#       229    0.001    0.000    2.406    0.011 /home/dpolimen/Qrisp/src/qrisp/core/library.py:1256(QFT)
#       312    0.001    0.000    0.006    0.000 /home/dpolimen/Qrisp/src/qrisp/uncomputation/type_checker.py:119(is_qfree)
#      1158    0.001    0.000    0.034    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1840(cx)
#       577    0.001    0.000    0.076    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:187(register_qv)
#      1152    0.001    0.000    0.026    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1894(x)
#      5852    0.001    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_variable.py:1049(__getitem__)
#  3994/526    0.001    0.000    0.035    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/assumptions.py:497(getit)
# 3952/1900    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/traversal.py:119(_preorder_traversal)
#      7131    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/facts.py:582(_tell)
#      1097    0.001    0.000    0.241    0.000 /home/dpolimen/Qrisp/src/qrisp/core/library.py:83(h)
#      6646    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3265(_round_dispatcher)
#      1794    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/mpmath/libmp/libmpf.py:153(_normalize)
#   154/118    0.001    0.000    0.046    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/operations.py:52(__new__)
#       312    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:420(add_node)
#      1828    0.001    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/custom_control_environment.py:237(<dictcomp>)
#      7590    0.001    0.000    0.001    0.000 {built-in method builtins.callable}
# 3628/3376    0.001    0.000    0.002    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/basic.py:189(__hash__)
#       120    0.001    0.000    0.048    0.000 /home/dpolimen/Qrisp/src/qrisp/mcx_algs/balauca.py:38(hybrid_mcx)
#       636    0.001    0.000    0.008    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/utils/decorators.py:1242(inner_f)
#        92    0.001    0.000    0.023    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_variable.py:455(duplicate)
#        37    0.001    0.000    2.446    0.066 /home/dpolimen/Qrisp/src/qrisp/arithmetic/modular_arithmetic/modular_qft_addition.py:42(beauregard_adder)
#      4413    0.001    0.000    0.001    0.000 {built-in method time.time}
#      6894    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#       577    0.001    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:206(<listcomp>)
#    720/72    0.001    0.000    0.007    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/expr.py:3599(_expand_hint)
#      5916    0.001    0.000    0.011    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/algorithms/traversal/breadth_first_search.py:118(bfs_edges)
#      4653    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:533(_swapaxes_dispatcher)
#       636    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/function.py:156(freeze)
#   874/856    0.001    0.000    0.051    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/decorators.py:224(_func)
#       894    0.001    0.000    0.003    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:1181(_new)
#       203    0.001    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/control_environment.py:69(__init__)
#       108    0.001    0.000    0.037    0.000 /home/dpolimen/Qrisp/src/qrisp/core/library.py:141(mcx)
#       101    0.001    0.000    0.002    0.000 /usr/lib/python3.9/inspect.py:2150(_signature_from_function)
#       834    0.001    0.000    0.003    0.000 /usr/lib/python3.9/linecache.py:52(checkcache)
# 1422/1182    0.001    0.000    0.002    0.000 {built-in method builtins.any}
#       203    0.001    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/control_environment.py:118(__exit__)
#        40    0.001    0.000    0.006    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/polyutils.py:231(_parallel_dict_from_expr_no_gens)
#      1848    0.001    0.000    0.005    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/sympify.py:502(_sympify)
#       197    0.001    0.000    0.031    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_session.py:373(delete_qv)
#        29    0.001    0.000    0.012    0.000 /home/dpolimen/Qrisp/src/qrisp/uncomputation/unqomp.py:63(qc_from_dag)
#       101    0.001    0.000    0.004    0.000 /usr/lib/python3.9/inspect.py:1129(getfullargspec)
#         2    0.001    0.000    5.478    2.739 /home/dpolimen/quantum-elliptic-curve-logarithm/src/quantum/ec_arithmetic.py:36(kaliski_quantum)
#      2646    0.001    0.000    0.002    0.000 /usr/lib/python3.9/traceback.py:285(line)
#      8413    0.001    0.000    0.001    0.000 {method 'zfill' of 'str' objects}
#        58    0.001    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_variable.py:799(reduce)
#      1090    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/basic.py:162(__new__)
#        29    0.001    0.000    1.786    0.062 /home/dpolimen/Qrisp/src/qrisp/core/quantum_variable.py:1174(uncompute)
#       185    0.001    0.000    0.484    0.003 /home/dpolimen/Qrisp/src/qrisp/arithmetic/modular_arithmetic/modular_qft_addition.py:31(qft_basis_adder)
#       132    0.001    0.000    0.005    0.000 /home/dpolimen/Qrisp/src/qrisp/arithmetic/poly_tools.py:42(monomial_to_list)
#       687    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/reportviews.py:417(__init__)
#       480    0.001    0.000    0.010    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1882(h)
#      2229    0.001    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_modulus.py:356(__hash__)
#       636    0.001    0.000    0.002    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graph.py:1964(nbunch_iter)
#       203    0.001    0.000    0.097    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/control_environment.py:103(__enter__)
#      1540    0.001    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:1515(<listcomp>)
#       432    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numpy/core/getlimits.py:685(__init__)
#      1274    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:398(parent)
#        40    0.001    0.000    0.457    0.011 /home/dpolimen/Qrisp/src/qrisp/arithmetic/SBP_arithmetic.py:612(U_g_inpl_adder)
#       121    0.001    0.000    0.016    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:263(SwapGate)
#      1764    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#   874/856    0.001    0.000    0.044    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/decorators.py:99(binary_op_wrapper)
#       687    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:1085(in_degree)
#      6188    0.001    0.000    0.001    0.000 {built-in method _operator.index}
#       396    0.001    0.000    0.002    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/mpmath/libmp/libmpf.py:410(from_float)
#        36    0.001    0.000    1.422    0.039 /home/dpolimen/Qrisp/src/qrisp/uncomputation/uncomputation.py:41(auto_uncomputed_function)
#       184    0.001    0.000    0.009    0.000 /usr/lib/python3.9/traceback.py:200(extract_stack)
#       858    0.001    0.000    0.002    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:1466(__hash__)
#       344    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/mpmath/ctx_mp_python.py:47(__new__)
#       216    0.001    0.000    0.056    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/scipy/sparse/_base.py:1329(_get_index_dtype)
#     11075    0.001    0.000    0.001    0.000 {method 'getrandbits' of '_random.Random' objects}
#        24    0.001    0.000    1.262    0.053 /home/dpolimen/Qrisp/src/qrisp/arithmetic/comparisons.py:24(less_than_gate)
#       632    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/basic.py:386(__eq__)
#       132    0.001    0.000    0.006    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/simplify/radsimp.py:1043(fraction)
#        90    0.001    0.000    0.008    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:73(CPGate)
#      4872    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/basic.py:786(args)
#      1427    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/graph.py:59(__set__)
#        54    0.001    0.000    0.005    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/scipy/sparse/_coo.py:185(_check)
#       858    0.001    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:808(__hash__)
#       444    0.001    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/gate_wrap_environment.py:208(<listcomp>)
#        10    0.000    0.000    0.524    0.052 /home/dpolimen/Qrisp/src/qrisp/arithmetic/SBP_arithmetic.py:651(hybrid_mult)
#       120    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/evalf.py:1558(evalf)
#       636    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/mpmath/libmp/libmpf.py:64(dps_to_prec)
#       112    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#        54    0.000    0.000    0.251    0.005 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/scipy/sparse/_coo.py:27(__init__)
#      3307    0.000    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_float.py:807(__hash__)
#      1427    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/networkx/classes/digraph.py:37(__set__)
#       516    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/mpmath/libmp/libmpf.py:291(from_man_exp)
#       203    0.000    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/misc/utility.py:999(perm_unlock)
#       882    0.000    0.000    0.001    0.000 /usr/lib/python3.9/linecache.py:26(getline)
#       448    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/gate_wrap_environment.py:125(__init__)
#       192    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/mul.py:467(_gather)
#       304    0.000    0.000    0.001    0.000 /usr/lib/python3.9/inspect.py:2515(__init__)
#       130    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/basic.py:2007(_exec_constructor_postprocessors)
# ...
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:668(_eval_is_imaginary)
#        96    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/mul.py:653(<listcomp>)
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#        10    0.000    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_float.py:707(add_sign)
#         9    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_array.py:386(__setitem__)
#        30    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_float.py:737(sign)
#        42    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/mul.py:1528(_eval_is_antihermitian)
#        29    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/uncomputation/uncomputation.py:107(<listcomp>)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/ipykernel/iostream.py:550(_is_master_process)
#        30    0.000    0.000    0.002    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/mul.py:1476(_eval_is_extended_real)
#        54    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/mul.py:1265(<genexpr>)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/polyoptions.py:498(postprocess)
#        12    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/mul.py:2122(_keep_coeff)
#        18    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/symbol.py:344(__xnew_cached_)
#        37    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/core/library.py:1869(<listcomp>)
#         6    0.000    0.000    0.004    0.001 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:738(<listcomp>)
#        18    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:36(_addsort)
#         6    0.000    0.000    0.004    0.001 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:737(_eval_is_odd)
#        18    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/power.py:962(as_base_exp)
#        36    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/arithmetic/poly_tools.py:73(<lambda>)
#         6    0.000    0.000    0.007    0.001 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:790(<listcomp>)
#         1    0.000    0.000    0.001    0.001 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_float.py:1093(copy_qf)
#         6    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:642(<lambda>)
#         4    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/mul.py:297(<listcomp>)
#         7    0.000    0.000    0.001    0.000 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_float.py:376(encode)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/domains/mpelements.py:34(_set_mpc)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:214(<dictcomp>)
#         2    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/src/quantum/ec_arithmetic.py:4(to_montgomery)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.pow}
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/ipykernel/iostream.py:577(_schedule_flush)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:634(<lambda>)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:648(<lambda>)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.9/threading.py:1093(is_alive)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:646(<lambda>)
#        18    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:1229(_as_mpf_op)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_array.py:561(encode)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/polyoptions.py:629(postprocess)
#         6    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:638(<lambda>)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:650(<lambda>)
#         2    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/scipy/sparse/_base.py:90(_csc_container)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:644(<lambda>)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:827(_eval_is_extended_nonnegative)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:636(<lambda>)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:640(<lambda>)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/mpmath/ctx_mp_python.py:620(<lambda>)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/polyoptions.py:533(postprocess)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/mpmath/ctx_mp_python.py:180(__gt__)
#        18    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:1242(_eval_is_integer)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/mpmath/libmp/libmpf.py:636(mpf_gt)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/polyoptions.py:591(postprocess)
#        12    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:643(<genexpr>)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/mpmath/ctx_mp_python.py:179(__lt__)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:842(_eval_is_extended_nonpositive)
#         3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:744(_eval_is_irrational)
#        48    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/expr.py:3672(_expand_hint_key)
#        29    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/control_environment.py:246(<listcomp>)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/polyoptions.py:332(default)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/polyoptions.py:518(postprocess)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:647(<genexpr>)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:655(_eval_is_infinite)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:874(<listcomp>)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:641(<genexpr>)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:651(<genexpr>)
#         3    0.000    0.000    0.000    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:652(<lambda>)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:635(<genexpr>)
#        12    0.000    0.000    0.001    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:639(<genexpr>)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/polyoptions.py:263(default)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:645(<genexpr>)
#        40    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/polys/polyoptions.py:276(default)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:649(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.9/cProfile.py:117(__exit__)
#         3    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/ipykernel/iostream.py:138(_event_pipe)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.9/threading.py:1039(_wait_for_tstate_lock)
#         1    0.000    0.000  131.456  131.456 /home/dpolimen/Qrisp/src/qrisp/environments/iteration_environment.py:148(__exit__)
#         6    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:1232(_argmin_dispatcher)
#         4    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:703(_eval_subs)
#        12    0.000    0.000    0.000    0.000 {built-in method sys.getrefcount}
#        24    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:652(<genexpr>)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/add.py:637(<genexpr>)
#         3    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_array.py:233(<listcomp>)
#         6    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_array.py:883(__array_finalize__)
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:3147(__neg__)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/standard_operations.py:211(Barrier)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/src/quantum/ec_arithmetic.py:127(qrisp_ell_double)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/iteration_environment.py:142(__enter__)
#         4    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:2250(__ne__)
#         1    0.000    0.000    0.001    0.001 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_float.py:790(init_from)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/circuit/quantum_circuit.py:2207(barrier)
#        21    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/core/compilation.py:388(<lambda>)
#        10    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/scipy/sparse/_csc.py:142(_swap)
#         6    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/environments/iteration_environment.py:121(__init__)
#         6    0.000    0.000    0.000    0.000 {method 'get' of 'ContextVar' objects}
#        12    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/expr.py:977(_eval_power)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/core/quantum_array.py:605(<listcomp>)
#         3    0.000    0.000    0.000    0.000 /usr/lib/python3.9/threading.py:529(is_set)
#         4    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/expr.py:3550(as_coeff_Mul)
#         4    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_bool.py:133(decoder)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/dateutil/tz/tz.py:218(utcoffset)
#         4    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/numbers.py:3203(__neg__)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/src/classical/ec_arithmetic.py:3(__init__)
#         4    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/sympy/core/basic.py:760(func)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/dateutil/tz/tz.py:262(_isdst)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_float.py:1095(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /home/dpolimen/Qrisp/src/qrisp/qtypes/quantum_float.py:1096(<listcomp>)

# %%
print(len([qb for qb in res[0].qs.qubits if qb.allocated]))
res_compiled = res[0].qs.compile()
print(res_compiled.depth())
print(res_compiled.transpile().count_ops())

# %%
print(qrisp.multi_measurement(res))
# Out:
# Simulating 37 qubits.. |███████████████████▌                                 | [ 37%]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/quantum-elliptic-curve-logarithm/venv/lib/python3.9/site-packages/numba/core/serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: _PyEval_EvalFrameDefault returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: _PyEval_EvalFrameDefault returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(qrisp.multi_measurement(res))
#
# File ~/Qrisp/src/qrisp/misc/utility.py:737, in multi_measurement(qv_list, shots, backend)
#     733     compiled_qc.measure(qubits, cl_reg)
#     735 # counts = execute(qs_temp, backend, basis_gates = basis_gates,
#     736 # noise_model = noise_model, shots = shots).result().get_counts()
# --> 737 counts = backend.run(compiled_qc, shots)
#     738 counts = {k: counts[k] for k in sorted(counts)}
#     740 # Convert the labeling bistrings of counts into list of labels
#
# File ~/Qrisp/src/qrisp/default_backend.py:37, in DefaultBackend.run(self, qc, shots, token)
#      35 def run(self, qc, shots, token = ""):
# ---> 37     return run(qc, shots, token)
#
# File ~/Qrisp/src/qrisp/simulator/simulator.py:154, in run(qc, shots, token, iqs, insert_reset)
#     148     iqs.disentangle(qubit_indices[0])
#     150 # If the operation is unitary, we apply this unitary on to the required
#     151 # qubit indices
#     152 else:
# --> 154     iqs.apply_operation(instr.op, qubit_indices)
#     156 # If all measurements have been performed, break
#     157 if measurement_counter == measurement_amount:
#
# File ~/Qrisp/src/qrisp/simulator/quantum_state.py:81, in QuantumState.apply_operation(self, operation, qubits)
#      78 unitary = operation.get_unitary()
#      80 # Apply the matrix
# ---> 81 entangled_factor.apply_matrix(unitary, qubits)
#      83 if entangled_factor.tensor_array.data.dtype == xp.dtype("O"):
#      84     return
#
# File ~/Qrisp/src/qrisp/simulator/tensor_factor.py:94, in TensorFactor.apply_matrix(self, matrix, qubits)
#      89 reshaped_tensor_array = self.tensor_array.reshape(
#      90     (matrix.shape[0], 2**self.n // matrix.shape[0])
#      91 )
#      93 # Apply matrix
# ---> 94 self.tensor_array = tensordot(
#      95     matrix, reshaped_tensor_array, axes=(1, 0), contract_sparsity_threshold=0.05
#      96 ).reshape(2**self.n)
#
# File ~/Qrisp/src/qrisp/simulator/bi_arrays.py:1345, in tensordot(a, b, axes, contract_sparsity_threshold)
#    1341             mp_wrapper()
#    1343         return res
# -> 1345 return a.contract(b, axes[0], axes[1])
#
# File ~/Qrisp/src/qrisp/simulator/bi_arrays.py:575, in SparseBiArray.contract(self, other, axes_self, axes_other)
#     573     res.thread.start()
#     574 else:
# --> 575     mp_wrapper()
#     577 return res
#
# File ~/Qrisp/src/qrisp/simulator/bi_arrays.py:548, in SparseBiArray.contract.<locals>.mp_wrapper()
#     542 sr_matrix_other = other.build_sr_matrix(
#     543     (contraction_size, other.size // contraction_size)
#     544 )
#     546 # Perform sparse matrix multiplication
# --> 548 res_sr_matrix = sparse_matrix_mult(sr_matrix_self, sr_matrix_other)
#     550 # Acquire flattened coordinates from the helper function
#     551 res.nz_indices = hlp.gen_flat_coords(
#     552     res_sr_matrix.col, res_sr_matrix.row, res_sr_matrix.shape
#     553 )
#
# File ~/Qrisp/src/qrisp/simulator/bi_arrays.py:54, in sparse_matrix_mult(a, b)
#      53 def sparse_matrix_mult(a, b):
# ---> 54     return hlp.sparse_matrix_mult(a, b)
#
# File ~/Qrisp/src/qrisp/simulator/bi_array_helper.py:547, in sparse_matrix_mult(A, B)
#     545     return (A @ B).tocoo()
#     546 else:
# --> 547     return  coo_sparse_matrix_mult(A, B)
#
# File ~/Qrisp/src/qrisp/simulator/bi_array_helper.py:509, in coo_sparse_matrix_mult(A, B)
#     507 def coo_sparse_matrix_mult(A, B):
#     508     if A.shape[0] < B.shape[1]:
# --> 509         new_row, new_col, new_data = coo_sparse_matrix_mult_jitted(A.row, A.col, A.data, B.row, B.col, B.data, A.shape, B.shape)
#     511     else:
#     513         new_col, new_row, new_data = coo_sparse_matrix_mult_jitted(B.col, B.row, B.data, A.col, A.row, A.data, B.shape[::-1], A.shape[::-1])
#
# SystemError: CPUDispatcher(<function coo_sparse_matrix_mult_jitted at 0x7f2902fa70d0>) returned a result with an error set
# Simulating 37 qubits.. |███████████████████▌                                 | [ 37%]
