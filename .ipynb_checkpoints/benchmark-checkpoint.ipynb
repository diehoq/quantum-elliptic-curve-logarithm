# %% [markdown]
# # Benchmarking ECDLP functions

# %%
import qrisp
import numpy as np
import src.classical.ec_arithmetic as clECarithm
import src.quantum.ec_arithmetic as qECarithm

# %%
def t_depth_indicator(op):
    if op.name in ["t", "t_dg"]:
        return 1
    else:
        return 0

def benchmark_circuit(res):
    
    compiled_circuit = res.qs.compile(compile_mcm = True, gate_speed = t_depth_indicator, workspace = res.size)
    qubit_count = compiled_circuit.num_qubits()
    gate_counts = compiled_circuit.transpile().count_ops()
    #print(gate_counts)
    cnot_count = gate_counts.get('cx', 0) + 0.5*gate_counts.get('c_if_cz', 0)
    t_count = gate_counts.get('t', 0) + gate_counts.get('t_dg', 0)
    t_depth = compiled_circuit.depth(depth_indicator = t_depth_indicator)  # Assumes depth of T gates aligns with circuit depth
    return {
        "qubit_count": qubit_count,
        "t_count": t_count,
        "cnot_count": cnot_count,
        "t_depth": t_depth
    }

# %%
p=7
a=5
b=4
curve = clECarithm.EllCurve(a, b, p)

# %%
benchmark_results_kaliski = {}
for val in range(1,p):
    v = qrisp.QuantumModulus(p, inpl_adder=qrisp.gidney_adder)
    v[:] = val
    m = qrisp.QuantumArray(qtype=qrisp.QuantumBool(), shape=(2 * p.bit_length(),))

    res_kaliski = qECarithm.kaliski_quantum(v, p, m)
    for a in m:
        a.delete()
    benchmark_results_kaliski[val] = benchmark_circuit(res_kaliski)

# %%
# Display results in a readable format
import pandas as pd
results_df = pd.DataFrame.from_dict(benchmark_results_kaliski, orient="index")
results_df.index.name = "Value of v"
print(results_df)
# Out:
#             qubit_count  t_count  cnot_count  t_depth
# Value of v
# 1                    30     2918      5651.0      855
# 2                    30     2918      5651.0      855
# 3                    30     2918      5651.0      855
# 4                    30     2918      5651.0      855
# 5                    30     2918      5651.0      855
# 6                    30     2918      5651.0      855

# %%
anc_values = [
    (2, 6),
    (4, 2),
    (0, 5),
    (5, 0),
]

x1 = qrisp.QuantumModulus(2**(p.bit_length()))
x1[:] = 1
mod_p = qrisp.QuantumModulus(p, inpl_adder=qrisp.gidney_adder)
G = [3, 2]

benchmark_results_ec_add = {}

for anc_pair in anc_values:
    anc = qrisp.QuantumArray(qtype=mod_p, shape=(2,))
    anc[:] = list(anc_pair)
    res_ec_add = qECarithm.qrisp_ell_add_inpl(anc, G, p)
    bm = benchmark_circuit(res_ec_add[0])
    benchmark_results_ec_add[tuple(anc_pair)] = bm

# %%
import pandas as pd
results_df = pd.DataFrame.from_dict(benchmark_results_ec_add, orient="index")
results_df.index.name = "Ancilla Values (anc)"
print(results_df)
# Out:
#      qubit_count  t_count  cnot_count  t_depth
# 2 6           64    16388     37331.5     3829
# 4 2           64    16388     37331.5     3829
# 0 5           64    16388     37331.5     3830
# 5 0           64    16388     37331.5     3838

# %%
x1 = qrisp.QuantumModulus(2**(p.bit_length()))
x1[:] = 1
mod_p = qrisp.QuantumModulus(p, inpl_adder=qrisp.gidney_adder)
G = [3, 2]

benchmark_results_ec_ctrl_add = {}

for anc_pair in anc_values:
    anc = qrisp.QuantumArray(qtype=mod_p, shape=(2,))
    anc[:] = list(anc_pair)
    res_ec_ctrl_add = qECarithm.qrisp_ell_add_inpl(anc, G, p)
    bm = benchmark_circuit(res_ec_ctrl_add[0])
    benchmark_results_ec_ctrl_add[tuple(anc_pair)] = bm

# %%
import pandas as pd
results_df = pd.DataFrame.from_dict(benchmark_results_ec_add, orient="index")
results_df.index.name = "Ancilla Values (anc)"
print(results_df)
# Out:
#      qubit_count  t_count  cnot_count  t_depth
# 2 6           64    16388     37331.5     3829
# 4 2           64    16388     37331.5     3829
# 0 5           64    16388     37331.5     3830
# 5 0           64    16388     37331.5     3838

# %%
# # WARNING: different EC
# curve = clECarithm.EllCurve(a, b, p)

# x1 = qrisp.QuantumModulus(2**(p.bit_length())) 
# x2 = qrisp.QuantumModulus(2**(p.bit_length()))

# mod_p = qrisp.QuantumModulus(p)
# #store registers
# anc = qrisp.QuantumArray(qtype=mod_p, shape=(2,))
# #initialize the store register to the point P_0 = [3,2]
# anc[:] = [3,2]

# #Generator G = [3,2]
# G = [3,2]

# #P = (3,3)
# P = [3,3]

# #Superposition
# qrisp.h(x1)
# qrisp.h(x2)

# #Multiplication step: anc = P0 + x1*G 
# anc = qECarithm.qrisp_ell_mult_add(G, anc, x1, curve)

# #Multiplication step: anc = anc - x2*P
# anc = qECarithm.qrisp_ell_mult_add(P, anc, x2, curve)

# #Quantum Fourier Transform on x1 and x2 registers
# qrisp.QFT(x1, inv=True)
# qrisp.QFT(x2, inv=True)

# Define the values of ancilla to test
anc_values = [
    (2, 6),
    (4, 2),
    (0, 5),
    (5, 0),
]


# Define the elliptic curve parameters and constants
curve = clECarithm.EllCurve(a, b, p)
mod_p = qrisp.QuantumModulus(p)
G = [3, 2]
P = [0, 2]

benchmark_results_mult_add = {}

for anc_pair in anc_values:
    print(anc_pair)
    anc = qrisp.QuantumArray(qtype=mod_p, shape=(2,))
    anc[:] = list(anc_pair)
    x1 = qrisp.QuantumModulus(2**(p.bit_length()))
    x2 = qrisp.QuantumModulus(2**(p.bit_length()))

    qrisp.h(x1)
    qrisp.h(x2)
    anc = qECarithm.qrisp_ell_mult_add(G, anc, x1, curve)
    anc = qECarithm.qrisp_ell_mult_add(P, anc, x2, curve)
    qrisp.QFT(x1, inv=True)
    qrisp.QFT(x2, inv=True)
    print(x2.qs.qv_list)

    bm = benchmark_circuit(anc[0])

    # Store results in the dictionary
    benchmark_results_mult_add[tuple(anc_pair)] = bm
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 63
#      60 qrisp.QFT(x1, inv=True)
#      61 qrisp.QFT(x2, inv=True)
# ---> 63 bm = benchmark_circuit(anc[0])
#      65 # Store results in the dictionary
#      66 benchmark_results_mult_add[tuple(anc_pair)] = bm
#
# Cell In[2], line 9, in benchmark_circuit(res)
#       7 def benchmark_circuit(res):
# ----> 9     compiled_circuit = res.qs.compile(compile_mcm = True, gate_speed = t_depth_indicator, workspace = res.size)
#      10     qubit_count = compiled_circuit.num_qubits()
#      11     gate_counts = compiled_circuit.transpile().count_ops()
#
# File ~\Desktop\GitHub\Qrisp\src\qrisp\core\quantum_session.py:1220, in QuantumSession.compile(self, workspace, intended_measurements, cancel_qfts, disable_uncomputation, compile_mcm, gate_speed)
#     770 r"""
#     771 Method to compile the QuantumSession into a :ref:`QuantumCircuit`. The compiler
#     772 dynamically allocates the qubits of the QuantumSession on qubits that might have
#    (...)
#    1216
#    1217 """
#    1218 from qrisp.core.compilation import qompiler
# -> 1220 return qompiler(
#    1221     self,
#    1222     workspace,
#    1223     disable_uncomputation=disable_uncomputation,
#    1224     intended_measurements=intended_measurements,
#    1225     cancel_qfts=cancel_qfts,
#    1226     compile_mcm=compile_mcm,
#    1227     gate_speed = gate_speed
#    1228 )
#
# File ~\Desktop\GitHub\Qrisp\src\qrisp\core\compilation.py:155, in qompiler(qs, workspace, disable_uncomputation, intended_measurements, cancel_qfts, compile_mcm, gate_speed, use_dirty_anc_for_mcx_recomp)
#     151             raise e
#     153 # Reorder circuit for parallelization.
#     154 # For more details check the implementation of this function
# --> 155 qc = parallelize_qc(qc, depth_indicator = gate_speed)
#     156 qc = cancel_inverses(qc)
#     158 # We now reorder the transpiled circuit to achieve a good (de)allocation order.
#     159 # Reordering is performed based on the DAG representation of Unqomp.
#     160 # The advantage of this representation is that
#    (...)
#     173 # previous order which might have been intentionally picked to optimize depth.
#     174 # In summary: Transpiling more aggressively leads to less qubits but more depth.
#
# File ~\Desktop\GitHub\Qrisp\src\qrisp\permeability\qc_transformations\qc_parallelization.py:133, in parallelize_qc(qc, depth_indicator)
#     130 qubit_ints = np.array(qubit_ints, dtype = np.uint64)
#     132 # Execute topological sort
# --> 133 res = depth_sensitive_topological_sort_jitted(
#     134     sprs_mat.indices, sprs_mat.indptr, qubit_ints, num_qubits=qc.num_qubits(), depth_indicators = np.array(depth_indicators)
#     135 )
#     137 # Build new circuit
#     138 qc_new = qc.clearcopy()
#
# File ~\Anaconda3\envs\qrisp\lib\site-packages\numba\core\serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      26 # Keep unpickled object via `numba_unpickle` alive.
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#      44     key = (address, hashed)
#
# KeyboardInterrupt:

# %%
# Display results in a readable format
import pandas as pd
results_df = pd.DataFrame.from_dict(benchmark_results_mult_add, orient="index")
results_df.index.name = "Ancilla Values (anc)"
results_df.columns.name = "Benchmark Metrics"
print(results_df)
# Out:
# Benchmark Metrics  qubit_count  t_count  cnot_count  t_depth
# 3 2                         42    85842    280200.0    37262
# 4 2                         48   171684    560400.0    74505
# 0 5                         54   257526    840588.0   111726
# 5 0                         60   343368   1120776.0   148917
# 0 2                         66   429210   1400964.0   186029
# 4 5                         72   515052   1681164.0   204642
# 2 1                         78   600894   1961364.0   223272
# 3 5                         84   686736   2241564.0   241873

# %%
# benchmark_results = {}

# benchmark_results["kaliski_quantum"] = benchmark_circuit(res_kaliski)
# benchmark_results["ec_addition"] = benchmark_circuit(res_ec_add[0])
# benchmark_results["controlled_addition"] = benchmark_circuit(res_ec_ctrl_add[0])
# benchmark_results["Shor's algorithm"] = benchmark_circuit(anc[0])

# %%
# import pandas as pd

# # Display results in a tabular format
# results_df = pd.DataFrame(benchmark_results).T
# print(results_df)
